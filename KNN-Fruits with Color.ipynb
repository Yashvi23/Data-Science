# %%
import pandas as pd

# %%
df = pd.read_table('https://storage.googleapis.com/kagglesdsdata/datasets%2F9590%2F13660%2Ffruit_data_with_colors.txt?GoogleAccessId=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com&Expires=1599670857&Signature=o8h3JkKsfCiODee1vzrSuGjlonUcalhnbi4L7dIAXdtim4fDEqR%2BSM%2FeVZ50%2FsGy8zaZL8rhkc3lh0mtCD4Tu5Fq%2FtPcDcWTZ2gCvfXGL0cP%2F9fi6Xm4cVarQhH%2Fi%2BCgWVYU2X4ToFgF5%2FCpZcToev17Nc3gqPhBTXLA%2Fh5vbXYqLruO1w0WE%2FJq5cGEIAIFR%2B%2FB1pq7yQK3S9YZ8vf%2FS92tlmxCAhiiJ1YuxYauzeak1IWfBFxBfHqWa3cSTAccgIj%2FSAzHO4SWrNo6j5uPd%2BwzBY4FXLM3AZ%2F0%2Bg0F%2B0RXiISNoy4tprUYcWqmGnjvVgWWZ%2F1L%2BSaDB35HhhBNRA%3D%3D')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets%2F9590%2F13660%2Ffruit_data_with_colors.txt?GoogleAccessId=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com&Expires=1599670857&Signature=o8h3JkKsfCiODee1vzrSuGjlonUcalhnbi4L7dIAXdtim4fDEqR%2BSM%2FeVZ50%2FsGy8zaZL8rhkc3lh0mtCD4Tu5Fq%2FtPcDcWTZ2gCvfXGL0cP%2F9fi6Xm4cVarQhH%2Fi%2BCgWVYU2X4ToFgF5%2FCpZcToev17Nc3gqPhBTXLA%2Fh5vbXYqLruO1w0WE%2FJq5cGEIAIFR%2B%2FB1pq7yQK3S9YZ8vf%2FS92tlmxCAhiiJ1YuxYauzeak1IWfBFxBfHqWa3cSTAccgIj%2FSAzHO4SWrNo6j5uPd%2BwzBY4FXLM3AZ%2F0%2Bg0F%2B0RXiISNoy4tprUYcWqmGnjvVgWWZ%2F1L%2BSaDB35HhhBNRA%3D%3D',sep ='\t')
df.head() #first 5 dataset
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
#Backlash charachter-Tab Space \t in csv it is comma
df.shape
# Out:
# (59, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
df.columns
# Out:
# Index(['fruit_label', 'fruit_name', 'fruit_subtype', 'mass', 'width', 'height',
#        'color_score'],
#       dtype='object')

# %%
#WEdont need fruit label and fruit subtype 
#fruit name is the i/p and rest are o/p

# %%
df['fruit_name'].unique()
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
#Data visualization using seaborn

# %%
#inputs and outputs

# %%
x = df.iloc[:,3:7].values
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 0)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
x_train.shape
# Out:
# (44, 4)

# %%
#default percentage is 0.25

# %%
x_test.shape
# Out:
# (15, 4)

# %%
#normalization
#from sklearn.processing import MinMaxScalar
#scaler = MinMaxScalar()
#x_train=scaler.fit_transform(x_train)
#x_test=scaler.transform(x_test)

# %%
model = KNeighborsClassifier(n_neighbors=7)

# %%
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
y_pred #predicted o/p
# Out:
# array(['orange', 'apple', 'lemon', 'lemon', 'apple', 'apple', 'orange',
#        'lemon', 'apple', 'lemon', 'mandarin', 'apple', 'apple', 'apple',
#        'apple'], dtype=object)

# %%
y_test #freal o/p
# Out:
# array(['orange', 'orange', 'lemon', 'orange', 'apple', 'apple', 'orange',
#        'lemon', 'orange', 'apple', 'mandarin', 'apple', 'orange',
#        'orange', 'orange'], dtype=object)

# %%
#Evaluation technique for classification
#1. Accuracy score
#2. Confusion Matrix
#3. Classification Report - NLP

# %%
#Accuracy score
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 53.333333333333336

# %%
#Confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[3, 1, 0, 0],
#        [0, 2, 0, 0],
#        [0, 0, 1, 0],
#        [5, 1, 0, 2]])

# %%
#ACCURACY SCORE
(3+2+1+2)/15
# Out:
# 0.5333333333333333

# %%
#Imbalance data- Accuracy score isint that good
#We need precision ,Recall,F1-Score

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       0.38      0.75      0.50         4
#        lemon       0.50      1.00      0.67         2
#     mandarin       1.00      1.00      1.00         1
#       orange       1.00      0.25      0.40         8
#
#     accuracy                           0.53        15
#    macro avg       0.72      0.75      0.64        15
# weighted avg       0.77      0.53      0.50        15

# %%
#SCORE IMPROVEMENT - NORMALISATION(MINMAXSCALAR) (REFER THE WEBSITE)
#FOR TRAINING DATA - FIT TRANSFORM
#FOR TESTING DATA - ONLY TRANSFORM

# %%
#normalization
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train #since the 4 columns had wide range of data in them we transforemed it so that they fit in the same range of values
# Out:
# array([[0.27857143, 0.41176471, 0.49230769, 0.72972973],
#        [0.35      , 0.44117647, 0.93846154, 0.45945946],
#        [0.        , 0.        , 0.        , 0.7027027 ],
#        [0.27142857, 0.52941176, 0.50769231, 0.37837838],
#        [0.31428571, 0.41176471, 0.46153846, 0.67567568],
#        [0.2       , 0.        , 0.72307692, 0.48648649],
#        [0.3       , 0.35294118, 0.52307692, 0.7027027 ],
#        [0.27857143, 0.44117647, 0.50769231, 0.64864865],
#        [0.14285714, 0.02941176, 0.63076923, 0.48648649],
#        [0.30714286, 0.5       , 0.47692308, 0.75675676],
#        [0.14285714, 0.14705882, 0.56923077, 0.45945946],
#        [0.45714286, 0.5       , 0.8       , 0.59459459],
#        [0.28571429, 0.55882353, 0.47692308, 0.37837838],
#        [0.01428571, 0.        , 0.04615385, 0.59459459],
#        [0.47857143, 0.58823529, 0.61538462, 0.72972973],
#        [0.28571429, 0.52941176, 0.53846154, 0.32432432],
# ...

# %%
model = KNeighborsClassifier(n_neighbors=7)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       0.38      0.75      0.50         4
#        lemon       0.50      1.00      0.67         2
#     mandarin       1.00      1.00      1.00         1
#       orange       1.00      0.25      0.40         8
#
#     accuracy                           0.53        15
#    macro avg       0.72      0.75      0.64        15
# weighted avg       0.77      0.53      0.50        15

# %%
y1 = scaler.transform([[176,7.4,7.2,0.60]])
y1=model.predict(y1)
y1
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-93-a91fbf183178> in <module>()
#       1 y1 = scaler.transform([[176,7.4,7.2,0.60]])
# ----> 2 y1=model.predict(y1)
#       3 y1
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     171         X = check_array(X, accept_sparse='csr')
#     172
# --> 173         neigh_dist, neigh_ind = self.kneighbors(X)
#     174         classes_ = self.classes_
#     175         _y = self._y
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     582
#     583         """
# --> 584         check_is_fitted(self)
#     585
#     586         if n_neighbors is None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     965
# ...

# %%
y1
